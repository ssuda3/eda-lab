# %%
import pandas as pd
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
df = pd.read_csv("train.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
df.shape
# Out:
# (891, 12)

# %% [markdown]
# ###Are the variables Categorical or Continuous?

# %%
df.Sex.value_counts()
# Out:
# male      577
# female    314
# dtype: int64

# %% [markdown]
# #####Sex is Categorical

# %%
df.PassengerId.value_counts()
# Out:
# 891    1
# 293    1
# 304    1
# 303    1
# 302    1
# 301    1
# 300    1
# 299    1
# 298    1
# 297    1
# 296    1
# 295    1
# 294    1
# 292    1
# 306    1
# ...
# 601    1
# 600    1
# 599    1
# 598    1
# 597    1
# 596    1
# 595    1
# 594    1
# 593    1
# 592    1
# 591    1
# 590    1
# 589    1
# 588    1
# 1      1
# Length: 891, dtype: int64

# %% [markdown]
# #####PassengerId is Categorical

# %%
df.Survived.value_counts()
# Out:
# 0    549
# 1    342
# dtype: int64

# %% [markdown]
# #####Survived is Categorical and there are a total of 342 survivors

# %%
df.Pclass.value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# dtype: int64

# %% [markdown]
# #####Pclass is Categorical

# %%
df.Age.value_counts()
# Out:
# 24    30
# 22    27
# 18    26
# 28    25
# 30    25
# 19    25
# 21    24
# 25    23
# 36    22
# 29    20
# 32    18
# 35    18
# 27    18
# 26    18
# 16    17
# ...
# 53.00    1
# 70.50    1
# 14.50    1
# 0.92     1
# 74.00    1
# 36.50    1
# 80.00    1
# 12.00    1
# 55.50    1
# 34.50    1
# 24.50    1
# 66.00    1
# 23.50    1
# 0.67     1
# 20.50    1
# Length: 88, dtype: int64

# %% [markdown]
# #####Age is Continuous

# %%
df.SibSp.value_counts()
# Out:
# 0    608
# 1    209
# 2     28
# 4     18
# 3     16
# 8      7
# 5      5
# dtype: int64

# %% [markdown]
# #####SibSp is Continuous

# %%
df.Parch.value_counts()
# Out:
# 0    678
# 1    118
# 2     80
# 5      5
# 3      5
# 4      4
# 6      1
# dtype: int64

# %% [markdown]
# #####Parch is Continuous

# %%
df.Ticket.value_counts()
# Out:
# CA. 2343        7
# 347082          7
# 1601            7
# 347088          6
# CA 2144         6
# 3101295         6
# 382652          5
# S.O.C. 14879    5
# PC 17757        4
# 4133            4
# LINE            4
# 349909          4
# 347077          4
# W./C. 6608      4
# 113760          4
# ...
# STON/O 2. 3101273    1
# 345777               1
# STON/O 2. 3101274    1
# STON/O 2. 3101275    1
# 113794               1
# 2649                 1
# 374887               1
# 349213               1
# 349210               1
# 349242               1
# 349216               1
# 112052               1
# 315088               1
# 349215               1
# W./C. 14258          1
# Length: 681, dtype: int64

# %% [markdown]
# #####Ticket is continuous

# %%
df.Fare.value_counts()
# Out:
# 8.0500     43
# 13.0000    42
# 7.8958     38
# 7.7500     34
# 26.0000    31
# 10.5000    24
# 7.9250     18
# 7.7750     16
# 7.2292     15
# 26.5500    15
# 0.0000     15
# 7.2500     13
# 7.8542     13
# 8.6625     13
# 7.2250     12
# ...
# 15.0000    1
# 28.7125    1
# 61.1750    1
# 6.2375     1
# 15.1000    1
# 39.4000    1
# 81.8583    1
# 61.9792    1
# 7.8000     1
# 22.0250    1
# 47.1000    1
# 13.4167    1
# 14.1083    1
# 15.5500    1
# 13.7917    1
# Length: 248, dtype: int64

# %% [markdown]
# #####Fare is Continuous

# %%
df.Cabin.value_counts()
# Out:
# C23 C25 C27        4
# G6                 4
# B96 B98            4
# D                  3
# C22 C26            3
# E101               3
# F2                 3
# F33                3
# B57 B59 B63 B66    2
# C68                2
# B58 B60            2
# E121               2
# D20                2
# E8                 2
# E44                2
# ...
# E50    1
# A14    1
# C91    1
# A16    1
# B38    1
# B39    1
# C95    1
# B78    1
# B79    1
# C99    1
# B37    1
# A19    1
# E12    1
# A7     1
# D15    1
# Length: 147, dtype: int64

# %% [markdown]
# #####Cabin is Continuous

# %%
df.Embarked.value_counts()
# Out:
# S    644
# C    168
# Q     77
# dtype: int64

# %% [markdown]
# #####Embarked is Categorical

# %%
df[df.PassengerId.isnull()]
###to check if PassenegrID has null values
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
df[df.Survived.isnull()]
###to check if Survived has null values
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
df[df.Pclass.isnull()]
###to check if Pclass has null values
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
df[df.Name.isnull()]
###to check if Name has null values
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
df[df.Sex.isnull()]
###to check if Sex has null values
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
df[df.Age.isnull()]
###to check if Age has null values
# Out:
#      PassengerId  Survived  Pclass  \
# 5              6         0       3
# 17            18         1       2
# 19            20         1       3
# 26            27         0       3
# 28            29         1       3
# 29            30         0       3
# 31            32         1       1
# 32            33         1       3
# 36            37         1       3
# 42            43         0       3
# 45            46         0       3
# 46            47         0       3
# 47            48         1       3
# 48            49         0       3
# 55            56         1       1
# 64            65         0       1
# 65            66         1       3
# 76            77         0       3
# 77            78         0       3
# 82            83         1       3
# 87            88         0       3
# 95            96         0       3
# 101          102         0       3
# 107          108         1       3
# 109          110         1       3
# ...

# %% [markdown]
# ####Age has 177 missing/null values

# %%
df[df.SibSp.isnull()]
###to check if SibSp has null values
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
df[df.Parch.isnull()]
###to check if Parch has null values
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
df[df.Ticket.isnull()]
###to check if Ticket has null values
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
df[df.Fare.isnull()]
###to check if Fare has null values
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
df[df.Cabin.isnull()]
###to check if Cabin has null values
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 2              3         1       3
# 4              5         0       3
# 5              6         0       3
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 22            23         1       3
# 24            25         0       3
# 25            26         1       3
# 26            27         0       3
# 28            29         1       3
# 29            30         0       3
# 30            31         0       1
# 32            33         1       3
# 33            34         0       2
# ...

# %% [markdown]
# ####Cabin has 687 missing/null values

# %%
df[df.Embarked.isnull()]
###to check if Cabin has null values
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 61            62         1       1                        Icard, Miss. Amelie
# 829          830         1       1  Stone, Mrs. George Nelson (Martha Evelyn)
#
#         Sex  Age  SibSp  Parch  Ticket  Fare Cabin Embarked
# 61   female   38      0      0  113572    80   B28      NaN
# 829  female   62      0      0  113572    80   B28      NaN

# %% [markdown]
# ####Embarked has 2 missing/null values

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# ####Max, Min, Avg, Mean values of continuous values

# %%
df.Survived.value_counts().plot(kind='bar')

# %% [markdown]
# ####bar graph for survived

# %%
df.Pclass.value_counts().plot(kind='bar')

# %% [markdown]
# ####bar graph for Pclass

# %%
df.Age.value_counts().plot(kind='bar')

# %% [markdown]
# ####bar graph for Age

# %%
df.SibSp.value_counts().plot(kind='bar')

# %% [markdown]
# ####bar graph for SibSp

# %%
df.Parch.value_counts().plot(kind='bar')

# %% [markdown]
# ####bar graph for Parch

# %%
df.Fare.value_counts().plot(kind='bar')

# %% [markdown]
# ####bar graph for Fare

# %%
df.Fare
# Out:
# 0      7.2500
# 1     71.2833
# 2      7.9250
# 3     53.1000
# 4      8.0500
# 5      8.4583
# 6     51.8625
# 7     21.0750
# 8     11.1333
# 9     30.0708
# 10    16.7000
# 11    26.5500
# 12     8.0500
# 13    31.2750
# 14     7.8542
# ...
# 876     9.8458
# 877     7.8958
# 878     7.8958
# 879    83.1583
# 880    26.0000
# 881     7.8958
# 882    10.5167
# 883    10.5000
# 884     7.0500
# 885    29.1250
# 886    13.0000
# 887    30.0000
# 888    23.4500
# 889    30.0000
# 890     7.7500
# Name: Fare, Length: 891, dtype: float64

# %%
df[df.Fare.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
df[df.Fare==0]
# Out:
#      PassengerId  Survived  Pclass                              Name   Sex  \
# 179          180         0       3               Leonard, Mr. Lionel  male
# 263          264         0       1             Harrison, Mr. William  male
# 271          272         1       3      Tornquist, Mr. William Henry  male
# 277          278         0       2       Parkes, Mr. Francis "Frank"  male
# 302          303         0       3   Johnson, Mr. William Cahoone Jr  male
# 413          414         0       2    Cunningham, Mr. Alfred Fleming  male
# 466          467         0       2             Campbell, Mr. William  male
# 481          482         0       2  Frost, Mr. Anthony Wood "Archie"  male
# 597          598         0       3               Johnson, Mr. Alfred  male
# 633          634         0       1     Parr, Mr. William Henry Marsh  male
# 674          675         0       2        Watson, Mr. Ennis Hastings  male
# ...

# %% [markdown]
# ###The list of passengers who did not pay any fare to bord the ship

# %%
df[df.SibSp==0]
# Out:
#      PassengerId  Survived  Pclass  \
# 2              3         1       3
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 8              9         1       3
# 11            12         1       1
# 12            13         0       3
# 14            15         0       3
# 15            16         1       2
# 17            18         1       2
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 26            27         0       3
# 28            29         1       3
# 29            30         0       3
# 30            31         0       1
# 32            33         1       3
# 33            34         0       2
# 36            37         1       3
# 37            38         0       3
# 42            43         0       3
# 44            45         1       3
# ...

# %% [markdown]
# ###There are 608 passengers who did not have siblings/Spouses aboard the ship

# %%
df[df.Parch==0]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 9             10         1       2
# 11            12         1       1
# 12            13         0       3
# 14            15         0       3
# 15            16         1       2
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 26            27         0       3
# 28            29         1       3
# 29            30         0       3
# 30            31         0       1
# 31            32         1       1
# 32            33         1       3
# ...

# %% [markdown]
# ###There are 678 people that do not have parents or children aboard the ship
